# %%
import pandas as pd
import plotly as py
import plotly.graph_objs as go
import ipywidgets as widgets
import numpy as np
from scipy import special
import plotly.express as px
import plotly.figure_factory as ff

py.offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.3.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('../Data/us_cities_with_lat_lon.csv')
df.head()
# Out:
#          country billing_city  billing_region  sum   latitude   longitude  \
# 0  United States    Abbeville         Alabama   30  31.575479  -85.279044
# 1  United States    Abbeville       Louisiana   62  29.958828  -92.142655
# 2  United States    Abbeville  South Carolina   40  34.181860  -82.378452
# 3  United States   Abbotsford       Wisconsin   42  44.964057  -90.299438
# 4  United States     Aberdeen           Idaho  152  42.976717 -112.818124
#
#   sum actual
# 0       $30
# 1       $62
# 2       $40
# 3       $42
# 4      $152

# %%
len(df)
# Out:
# 11553

# %%
df_sales=df.loc[df['sum'] >= 1]
df_sales.head()
# Out:
#          country billing_city  billing_region  sum   latitude   longitude  \
# 0  United States    Abbeville         Alabama   30  31.575479  -85.279044
# 1  United States    Abbeville       Louisiana   62  29.958828  -92.142655
# 2  United States    Abbeville  South Carolina   40  34.181860  -82.378452
# 3  United States   Abbotsford       Wisconsin   42  44.964057  -90.299438
# 4  United States     Aberdeen           Idaho  152  42.976717 -112.818124
#
#   sum actual
# 0       $30
# 1       $62
# 2       $40
# 3       $42
# 4      $152

# %%
len(df_sales)
# Out:
# 11553

# %%
df_sales['text'] = df_sales['billing_city'] + ', ' + df_sales['billing_region'] + '  $' +  df_sales['sum'].astype(str)

fig = go.Figure(data=go.Scattergeo(
        lon = df_sales['longitude'],
        lat = df_sales['latitude'],
        text = df_sales['text'],
        mode = 'markers',
        hovertemplate =
           '<i>City:</i>'+
           '<br><b>%{text}</b>',
        marker=dict(
            size=df_sales['sum']/600,
            color=df_sales['sum'],
            showscale=True,
            colorbar_title="Sales($)<br>2021"
            
        )
            
        ))

fig.update_layout(
        title_text = 'Vitamin Ventures - 2021 US Cities Sales<br>(Click legend to toggle traces)',
        
        geo = dict(
            scope = 'usa',
            landcolor = 'rgb(217, 217, 217)'
        )
    )


fig.show()
# Out:
# <div>                            <div id="df33ffd7-0ae4-4af4-9a3c-f3f62a5926f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df33ffd7-0ae4-4af4-9a3c-f3f62a5926f3")) {                    Plotly.newPlot(                        "df33ffd7-0ae4-4af4-9a3c-f3f62a5926f3",                        [{"hovertemplate":"<i>City:</i><br><b>%{text}</b>","lat":[31.575478999999998,29.958828000000004,34.18186,44.964057000000004,42.976717,39.510886,35.121641,45.466109,46.984293,33.849961,38.937144,32.468154999999996,40.802312,39.47444,36.691644000000004,42.116715,40.128141,30.483696000000002,39.462368,38.200413,39.635504,38.671991999999996,41.808308000000004,34.483540999999995,42.475076,41.6997,34.065833000000005,34.075627000000004,42.95661,47.315597,40.770931,34.780044000000004,34.359527,40.457571,36.558174,39.306452,30.355698999999998,34.205571,41.933509,32.961667,41.62214,34.584128,29.380542,36.677486,41.900515999999996,38.412473,37.092219,36.006496000000006,44.86965
# 8        Virginia  2021  114648  114647.765
# 5  North Carolina  2021  126278  126278.190
# 6    Pennsylvania  2021  129322  129321.910
# 3      New Jersey  2021  140342  140342.385
# 2        Illinois  2021  149560  149560.390

# %%
df_states['text'] = df_states['billing_region'] + '  $' + df_states['sum'].astype(str)
fig = px.bar(df_states, y='billing_region',
             x='sum',
             color="sum",
             text=df_states['text'],
             orientation='h',
             labels={"sum": "Sales ($)","billing_region":'US States'}, 
             title="Top 10 States in US - by 2021 Sales")
fig.update_traces(textposition='inside')

fig.show()
# Out:
# <div>                            <div id="35c89fd7-0c95-4824-aca8-b7f4d77cd04e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35c89fd7-0c95-4824-aca8-b7f4d77cd04e")) {                    Plotly.newPlot(                        "35c89fd7-0c95-4824-aca8-b7f4d77cd04e",                        [{"alignmentgroup":"True","hovertemplate":"Sales ($)=%{marker.color}<br>US States=%{y}<br>text=%{text}<extra></extra>","legendgroup":"","marker":{"color":[114648,126278,129322,140342,149560,160613,239539,259753,451655,858211],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"text":["Virginia  $114648","North Carolina  $126278","Pennsylvania  $129322","New Jersey  $140342","Illinois  $149560","Washington  $160613","Florida  $239539","New York  $259753","Texas  $451655","California  $858211"],"textposition":"inside","type":"bar","x":[114648,126278,129322,140342,149560,160613,239539,259753,451655,858211],"xaxis":"x","y":["Virginia","North Carolina","Pennsylvania","New Jersey","Illinois","Washington","Florida","New York","Texas","California"],"yaxis":"y"}],                        {"barmode":"relative","coloraxis":{"colorbar":{"title":{"text":"Sales ($)"}},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]},"legend":{"tracegroupgap":0},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[ ...

# %%
df_sales=df_sales.sort_values(by='sum', ascending=False)
df_top_10_cities = df_sales.iloc[0:10]
df_top_10_cities=df_top_10_cities.sort_values(by='sum', ascending=True)
df_top_10_cities.head()
# Out:
#             country billing_city billing_region    sum   latitude   longitude  \
# 2506  United States       Dallas          Texas  30033  32.790439  -96.804390
# 4502  United States      Hayward     California  35420  37.656400 -122.095700
# 9211  United States    San Diego     California  36850  32.718520 -117.159316
# 480   United States       Austin          Texas  37341  30.210692  -97.942749
# 1244  United States     Brooklyn       New York  38393  40.694021  -73.990340
#
#      sum actual                           text
# 2506   $30,033           Dallas, Texas  $30033
# 4502   $35,420     Hayward, California  $35420
# 9211   $36,850   San Diego, California  $36850
# 480    $37,341           Austin, Texas  $37341
# 1244   $38,393      Brooklyn, New York  $38393

# %%
df_top_10_cities['text'] = df_top_10_cities['billing_city'] + ', ' + df_top_10_cities['billing_region'] + '  $' + df_top_10_cities['sum'].astype(str)

# %%
fig = px.bar(df_top_10_cities, y='billing_city',
             x='sum',
             orientation='h',
             color="sum",
             text=df_top_10_cities['text'],
             labels={"sum": "Sales ($)","billing_city":'US Cities'}, 
             title="Top 10 Cities in US - by 2021 Sales")
fig.update_traces(textposition='inside')
fig.show()
# Out:
# <div>                            <div id="4966f0f7-4707-4e0e-939a-a38463b156dd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4966f0f7-4707-4e0e-939a-a38463b156dd")) {                    Plotly.newPlot(                        "4966f0f7-4707-4e0e-939a-a38463b156dd",                        [{"alignmentgroup":"True","hovertemplate":"Sales ($)=%{marker.color}<br>US Cities=%{y}<br>text=%{text}<extra></extra>","legendgroup":"","marker":{"color":[30033,35420,36850,37341,38393,39400,41067,45357,57076,69900],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"text":["Dallas, Texas  $30033","Hayward, California  $35420","San Diego, California  $36850","Austin, Texas  $37341","Brooklyn, New York  $38393","New York, New York  $39400","Bozeman, Montana  $41067","Chicago, Illinois  $45357","Houston, Texas  $57076","Los Angeles, California  $69900"],"textposition":"inside","type":"bar","x":[30033,35420,36850,37341,38393,39400,41067,45357,57076,69900],"xaxis":"x","y":["Dallas","Hayward","San Diego","Austin","Brooklyn","New York","Bozeman","Chicago","Houston","Los Angeles"],"yaxis":"y"}],                        {"barmode":"relative","coloraxis":{"colorbar":{"title":{"text":"Sales ($)"}},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]},"legend":{"tracegroupgap":0},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e" ...

# %%
df_country = pd.read_csv('../Data/countries_with_lat_lon.csv')
df_country.head()
# Out:
#                          country  sum  latitude  longitude  sum_actual
# 0                          India    9     20.00      77.00        8.50
# 1                    Saint Lucia   10     13.88     -61.13       10.00
# 2  Holy See (Vatican City State)   10     41.90      12.45       10.00
# 3                         Serbia   10     44.00      21.00       10.00
# 4                 Cayman Islands   20     19.50     -80.50       19.99

# %%
len(df_country)
# Out:
# 81

# %%
fig = px.scatter_geo(df_country,
                    lon = df_country['longitude'],
                    lat = df_country['latitude'],
                    color='country',
                    hover_name="country",
                    title='Vitamin Ventures - International Presence',
                    legend=False)
                    
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-780c9179603e> in <module>
# ----> 1 fig = px.scatter_geo(df_country,
#       2                     lon = df_country['longitude'],
#       3                     lat = df_country['latitude'],
#       4                     color='country',
#       5                     hover_name="country",
#
# NameError: name 'px' is not defined

# %%
df_country = pd.read_csv('../Data/countries_with_lat_lon.csv')
df_country_no_us = df_country[df_country['country']!='United States']
df_country_no_us.head()
# Out:
#                          country  sum  latitude  longitude  sum_actual
# 0                          India    9     20.00      77.00        8.50
# 1                    Saint Lucia   10     13.88     -61.13       10.00
# 2  Holy See (Vatican City State)   10     41.90      12.45       10.00
# 3                         Serbia   10     44.00      21.00       10.00
# 4                 Cayman Islands   20     19.50     -80.50       19.99

# %%
df_country_no_us['text'] = df_country_no_us['country'] + '  $' +  df_country_no_us['sum'].astype(str)

fig = go.Figure(data=go.Scattergeo(
        lon = df_country_no_us['longitude'],
        lat = df_country_no_us['latitude'],
        text = df_country_no_us['text'],
        mode = 'markers',
        hovertemplate =
           '<i>Country:</i>'+
           '<br><b>%{text}</b>',
        marker=dict(
            size=df_country_no_us['sum']/400,
            color=df_country_no_us['sum'],
            showscale=True,
            colorbar_title="Sales($)<br>2021"
            
        )
            
        ))

fig.update_layout(
        title_text = 'Vitamin Ventures - 2021 International Sales',
        
        geo = dict(
            scope = 'world',
            landcolor = 'rgb(217, 217, 217)'
        )
    )


fig.show()
# Out:
# <div>                            <div id="8c5a6830-0440-4c00-b7e0-a148b757b0ec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8
550","Philippines  $1447","Hong Kong  $1435","Malaysia  $1422","Ireland  $1288","Mexico  $1273","Netherlands  $1223","Sweden  $1123","Cambodia  $1041","New Zealand  $942","Norway  $659","Japan  $521","Iceland  $483","El Salvador  $459","Panama  $406","Denmark  $370","Brazil  $357","Barbados  $350","Dominican Republic  $332","Belgium  $309","Egypt  $291","Spain  $249","Taiwan  $246","Ukraine  $240","South Korea  $233","Poland  $230","Bermuda  $218","Thailand  $217","Chile  $209","Lebanon  $201","Cyprus  $201","Austria  $188","Jordan  $185","Guatemala  $175","Germany  $167","Israel  $127","Colombia  $126","Czech Republic  $118","Russia  $116","Finland  $111","Jamaica  $109","Luxembourg  $101","Nigeria  $92","Romania  $92","South Africa  $90","Maldives  $87","Bahamas  $86","Lao People's Democratic Republic  $85","Portugal  $83","Pakistan  $82","Morocco  $67","China  $64","Sri Lanka  $50","Bulgaria  $49","Paraguay  $45","Namibia  $42","Jersey  $39","Venezuela  $27","Armenia  $27","Mauritania  $25","Peru  $25","French Polynesia  $22","Belize  $22","Cayman Islands  $20","Holy See (Vatican City State)  $10","Saint Lucia  $10","Serbia  $10","India  $9"],"type":"scattergeo"}],                        {"geo":{"landcolor":"rgb(217, 217, 217)","scope":"world"},"template":{"data":{" ...

# %%
df_country_no_us=df_country_no_us.sort_values(by='sum', ascending=False)
df_top_10_country_no_us = df_country_no_us.iloc[0:10]
df_top_10_country_no_us = df_top_10_country_no_us.sort_values(by='sum',ascending=True)
df_top_10_country_no_us.head()
# Out:
#       country    sum  latitude  longitude  sum_actual
# 70  Singapore   3532      1.37     103.80     3532.11
# 71     France   3644     46.00       2.00     3643.50
# 72    Bahrain   7535     26.00      50.55     7535.30
# 73      Qatar   8545     25.50      51.25     8544.86
# 74  Australia  12877    -27.00     133.00    12876.51

# %%
fig = px.bar(df_top_10_country_no_us, y='country',
             x='sum',
             color="sum",
             orientation='h',
             text='country',
             labels={"sum": "Sales ($)","country":'International Country'}, 
             title="Top 10 International Countries - by 2021 Sales")
fig.update_traces(textposition='inside')
fig.show()
# Out:
# <div>                            <div id="9fd24c1a-effd-48de-8ccc-52f43de887ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9fd24c1a-effd-48de-8ccc-52f43de887ee")) {                    Plotly.newPlot(                        "9fd24c1a-effd-48de-8ccc-52f43de887ee",                        [{"alignmentgroup":"True","hovertemplate":"Sales ($)=%{marker.color}<br>International Country=%{text}<extra></extra>","legendgroup":"","marker":{"color":[3532,3644,7535,8545,12877,15555,17132,21819,22126,66405],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"text":["Singapore","France","Bahrain","Qatar","Australia","United Kingdom","United Arab Emirates","Saudi Arabia","Kuwait","Canada"],"textposition":"inside","type":"bar","x":[3532,3644,7535,8545,12877,15555,17132,21819,22126,66405],"xaxis":"x","y":["Singapore","France","Bahrain","Qatar","Australia","United Kingdom","United Arab Emirates","Saudi Arabia","Kuwait","Canada"],"yaxis":"y"}],                        {"barmode":"relative","coloraxis":{"colorbar":{"title":{"text":"Sales ($)"}},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]},"legend":{"tracegroupgap":0},"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#f ...
