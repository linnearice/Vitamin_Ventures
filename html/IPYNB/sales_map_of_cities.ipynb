# %%
import pandas as pd
import plotly as py
import plotly.graph_objs as go
import ipywidgets as widgets
import numpy as np
from scipy import special
import plotly.express as px
import plotly.figure_factory as ff

py.offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('../Data/us_cities_with_lat_lon.csv')
df.head()
# Out:
#          country billing_city  billing_region  sum   latitude   longitude  \
# 0  United States    Abbeville         Alabama   30  31.575479  -85.279044
# 1  United States    Abbeville       Louisiana   62  29.958828  -92.142655
# 2  United States    Abbeville  South Carolina   40  34.181860  -82.378452
# 3  United States   Abbotsford       Wisconsin   42  44.964057  -90.299438
# 4  United States     Aberdeen           Idaho  152  42.976717 -112.818124
#
#   sum actual
# 0       $30
# 1       $62
# 2       $40
# 3       $42
# 4      $152

# %%
df['text'] = df['billing_city'] + '<br>Net Sales ' + (df['sum']/1e6).astype(str)+' million'
limits = [(0,2),(3,10),(11,20),(21,50),(50,3000)]
colors = ["royalblue","crimson","lightseagreen","orange","lightgrey"]
cities = []
scale = 5000

fig = go.Figure()

for i in range(len(limits)):
    lim = limits[i]
    df_sub = df[lim[0]:lim[1]]
    fig.add_trace(go.Scattergeo(
        locationmode = 'USA-states',
        lon = df_sub['longitude'],
        lat = df_sub['latitude'],
        text = df_sub['text'],
        marker = dict(
            size = df_sub['sum']/scale,
            color = colors[i],
            line_color='rgb(40,40,40)',
            line_width=0.5,
            sizemode = 'area'
        ),
        name = '{0} - {1}'.format(lim[0],lim[1])))

fig.update_layout(
        title_text = '2021 Vitamin Ventures Sales<br>(Click legend to toggle traces)',
        showlegend = True,
        geo = dict(
            scope = 'usa',
            landcolor = 'rgb(217, 217, 217)',
        )
    )

fig.show()
# Out:
# <div>                            <div id="70223455-d928-4daf-8d9b-875f23c47f81" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("70223455-d928-4daf-8d9b-875f23c47f81")) {                    Plotly.newPlot(                        "70223455-d928-4daf-8d9b-875f23c47f81",                        [{"lat":[31.575479,29.958828],"locationmode":"USA-states","lon":[-85.279044,-92.142655],"marker":{"color":"royalblue","line":{"color":"rgb(40,40,40)","width":0.5},"size":[0.006,0.0124],"sizemode":"area"},"name":"0 - 2","text":["Abbeville<br>Net Sales 3e-05 million","Abbeville<br>Net Sales 6.2e-05 million"],"type":"scattergeo"},{"lat":[44.964057,42.976717,39.510886,35.121641,45.466109,46.984293,33.849961],"locationmode":"USA-states","lon":[-90.299438,-112.818124,-76.18054,-79.445039,-98.485642,-123.79629,-101.861111],"marker":{"color":"crimson","line":{"color":"rgb(40,40,40)","width":0.5},"size":[0.0084,0.0304,0.077,0.0794,0.0398,0.033,0.004],"sizemode":"area"},"name":"3 - 10","text":["Abbotsford<br>Net Sales 4.2e-05 million","Aberdeen<br>Net Sales 0.000152 million","Aberdeen<br>Net Sales 0.000385 million","Aberdeen<br>Net Sales 0.000397 million","Aberdeen<br>Net Sales 0.000199 million","Aberdeen<br>Net Sales 0.000165 million","Abernathy<br>Net Sales 2e-05 million"],"type":"scattergeo"},{"lat":[32.468155,40.802312,39.47444,36.691644,42.116715,40.128141,30.483696,39.462368,38.200413],"locationmode":"USA-states","lon":[-99.718208,-90.400898,-76.299726,-82.019989,-70.954293,-75.128918,-90.004072,-74.503106,-121.218576],"marker":{"color":"lightseagreen","line":{"color":"rgb(40,40,40)","width":0.5},"size":[0.4688,0.0092,0.1316,0.0596,0.0182,0.038,0.0024,0.0166,0.0166],"sizemode":"area"},"name":"11 - 20","text":["Abilene<br>Net Sales 0.002344 million","Abingdon<br>Net Sales 4.6e-05 million","Abingdon<br>Net Sales 0.000658 million","Abingdon<br>Net Sales 0.000298 million","Abington<br>Net Sales 9.1e-05 million","Abington<br>Net Sales 0.00019 million","Abita Springs<br>Net Sales 1.2e-05 million","Absecon<br>Net Sales 8.3e-05 million","Acampo<br>Net Sales 8.3e-05 million"],"type":"scattergeo"},{"lat":[38.671992,41.808308,34.483541,42.475076,41.6997,34.065833,34.075627,42.95661,47.315597,40.770931,34.780044,34.359527,40.457571,36.558174,39.306452,30.355699,34.205571,41.933509,32.961667,41.62214,34.584128,29.380542,36.677486,41.900516,38.412473,37.092219,36.006496,44.86965,42.241737],"locationmode":"USA-states","lon":[-77.016217,-74.235336,-118.195929,-71.448255,-70.908652,-84.676944,-84.647741,-85.480959,-96.503569,-83.815402,-96.69236,-84.917634,-96.53956,-87.122626,-77.447693,-91.261348,-87.194766,-88.0054,-96.828889,-94.037965,-117.424189,-98.26504,-86.263596,-84.044556,-94.368336,-89.910614,-80.446301,-92.823358,-75.536604],"marker":{"color":"orange","line":{"color":"rgb(40,40,40)","width":0.5},"size":[0.0044,0.001,0.0574,0.0924,0.0038,0.4704,0.4704,0.0284,0.0072,0.005,0.0394,0.0356,0.001,0.005,0.0044,0.031,0.0032,0.0678,0.063,0.0598,0.0526,0.02,0.002,0.0688,0.0064,0.002,0.0244,0.0184,0.0018],"sizemode":"area"},"name":"21 - 50","text":["Accokeek<br>Net Sales 2.2e-05 million","Accord<br>Net Sales 5e-06 million","Acton<br>Net Sales 0.000287 million","Acton<br>Net Sales 0.000462 million","Acushnet<br>Net Sales 1.9e-05 million","Acworth<br>Net Sales 0.002352 million","Acworth<br>Net Sales 0.002352 million","Ada<br>Net Sales 0.000142 million","Ada<br>Net Sales 3.6e-05 million","Ada<br>Net Sales 2.5e-05 million","Ada<br>Net Sales 0.000197 million","Adairsville<br>Net Sales 0.000178 million","Adams<br>Net Sales 5e-06 million","Adams<br>Net Sales 2.5e-05 million","Adamstown<br>Net Sales 2.2e-05 million","Addis<br>Net Sales 0.000155 million","Addison<br>Net Sales 1.6e-05 million","Addison<br>Net Sales 0.000339 million","Ad ...

# %%
df['text'] = df['billing_city'] + ', ' + df['billing_region'] + '' + 'Net Sales: ' + df['sum'].astype(str)

fig = go.Figure(data=go.Scattergeo(
        lon = df['longitude'],
        lat = df['latitude'],
        text = df['text'],
        mode = 'markers',
        marker_color = df['sum'],
    #marker = dict(
     #       size = df_sub['sum']/scale,
      #      color = colors[i],
       #     line_width=0.5,
        #    sizemode = 'area'
        #)
        ))

fig.update_layout(
        title = 'Vitamin Ventures - Net Sales<br>(Hover for state names)',
        geo_scope='usa',
    )
fig.show()
# Out:
# <div>                            <div id="dd0b69c5-fd01-40dd-9dc6-50ce7a556773" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd0b69c5-fd01-40dd-9dc6-50ce7a556773")) {                    Plotly.newPlot(                        "dd0b69c5-fd01-40dd-9dc6-50ce7a556773",                        [{"lat":[31.575479,29.958828,34.18186,44.964057,42.976717,39.510886,35.121641,45.466109,46.984293,33.849961,38.937144,32.468155,40.802312,39.47444,36.691644,42.116715,40.128141,30.483696,39.462368,38.200413,39.635504,38.671992,41.808308,34.483541,42.475076,41.6997,34.065833,34.075627,42.95661,47.315597,40.770931